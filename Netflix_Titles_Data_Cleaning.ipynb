# %% [markdown]
# <a href="https://colab.research.google.com/github/bena47/-AI-Coursework-2025/blob/main/Netflix_Titles_Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("netflix_titles.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
import pandas as pd
import numpy as np

# Check for missing values
missing_values = df.isnull().sum()

# Display the count of missing values for each column
print("Missing values per column:")
print(missing_values)
# Out:
# Missing values per column:
# show_id            0
# type               0
# title              0
# director        2634
# cast             825
# country          831
# date_added        10
# release_year       0
# rating             4
# duration           3
# listed_in          0
# description        0
# dtype: int64

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("netflix_titles.csv")

df.describe(include=object)
# Out:
#        show_id   type   title       director                cast  \
# count     8807   8807    8807           6173                7982
# unique    8807      2    8807           4528                7692
# top      s8807  Movie  Zubaan  Rajiv Chilaka  David Attenborough
# freq         1   6131       1             19                  19
#
#               country       date_added rating  duration  \
# count            7976             8797   8803      8804
# unique            748             1767     17       220
# top     United States  January 1, 2020  TV-MA  1 Season
# freq             2818              109   3207      1793
#
#                            listed_in  \
# count                           8807
# unique                           514
# top     Dramas, International Movies
# freq                             362
#
#                                               description
# count                                                8807
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("netflix_titles.csv")

df.tail(20)
# Out:
#      show_id     type                          title                 director  \
# 8787   s8788    Movie      You Can’t Fight Christmas              Kenny Young
# 8788   s8789    Movie                   You Carry Me               Ivona Juka
# 8789   s8790    Movie            You Changed My Life      Cathy Garcia-Molina
# 8790   s8791    Movie  You Don't Mess with the Zohan             Dennis Dugan
# 8791   s8792    Movie                    Young Adult            Jason Reitman
# 8792   s8793    Movie                    Young Tiger                   Mu Chu
# 8793   s8794    Movie           Yours, Mine and Ours             Raja Gosnell
# 8794   s8795    Movie                         اشتباك             Mohamed Diab
# 8795   s8796  TV Show                Yu-Gi-Oh! Arc-V                      NaN
# 8796   s8797  TV Show                     Yunus Emre                      NaN
# 8797   s8798  TV Show                      Zak Storm                      NaN
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("netflix_titles.csv")

df.loc [df['country'] == 'South Africa']
# Out:
#      show_id     type                                   title  \
# 1         s2  TV Show                           Blood & Water
# 293     s294    Movie                                    Slay
# 764     s765    Movie            Trippin' with the Kandasamys
# 881     s882    Movie                          I Am All Girls
# 1172   s1173    Movie                 Loyiso Gola: Unlearning
# 1514   s1515  TV Show                            Diamond City
# 1535   s1536  TV Show                   How To Ruin Christmas
# 1593   s1594  TV Show                        Kings of Jo'Burg
# 1905   s1906    Movie                            Cold Harbour
# 2038   s2039    Movie                      My Octopus Teacher
# 2046   s2047    Movie                 Kandasamys: The Wedding
# 2187   s2188    Movie                        Seriously Single
# 2216   s2217    Movie                       The Letter Reader
# 2244   s2245    Movie                        Hole in the Wall
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("netflix_titles.csv")

df.iloc[12,11]
# Out:
# 'After most of her family is murdered in a terrorist bombing, a young woman is unknowingly lured into joining the very group that killed them.'

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("netflix_titles.csv")

df.query("country == 'South Africa' & release_year == 2021")
# Out:
#      show_id     type                         title       director  \
# 1         s2  TV Show                 Blood & Water            NaN
# 293     s294    Movie                          Slay      Adze Ugah
# 764     s765    Movie  Trippin' with the Kandasamys  Jayan Moodley
# 881     s882    Movie                I Am All Girls  Donovan Marsh
# 1172   s1173    Movie       Loyiso Gola: Unlearning  Kagiso Lediga
#
#                                                    cast       country  \
# 1     Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...  South Africa
# 293   Enhle Mbali, Ramsey Nouah, Dawn Thandeka Kang,...  South Africa
# 764   Jailoshini Naidoo, Maeshni Naicker, Madhushan ...  South Africa
# 881   Erica Wessels, Hlubi Mboya, Deon Lotz, Brendon...  South Africa
# 1172                                        Loyiso Gola  South Africa
#
#               date_added  release_year rating   duration  \
# 1     September 24, 2021          2021  TV-MA  2 Seasons
# ...

# %%
import pandas as pd
import numpy as np
df = pd.read_csv("netflix_titles.csv")

movies_2021_cast = df.query("type == 'Movie' & release_year == 2021")['cast']
display(movies_2021_cast)
# Out:
# 6       Vanessa Hudgens, Kimiko Glenn, James Marsden, ...
# 9       Melissa McCarthy, Chris O'Dowd, Kevin Kline, T...
# 12      Luna Wedler, Jannis Niewöhner, Milan Peschel, ...
# 13      Klara Castanho, Lucca Picon, Júlia Gomes, Marc...
# 18      Freida Pinto, Logan Marshall-Green, Robert Joh...
#                               ...
# 1425                                                  NaN
# 1431    Engin Günaydın, Haluk Bilginer, Binnur Kaya, Ö...
# 1436    Juan Sebastián Gutiérrez, Pablo Cano, Pablo Me...
# 1466                                                  NaN
# 1468             Cha In-pyo, Cho Dal-hwan, Song Jae-ryong
# Name: cast, Length: 277, dtype: object
